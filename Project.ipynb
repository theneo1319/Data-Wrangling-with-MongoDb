# %% [markdown]
# # Open Street Map Data - Part of Hyderabad

# %% [markdown]
# The file 'Hyderabad_part' is downloaded from https://mapzen.com/data/metro-extracts/. I selected a part of Hyderabad to procede with my analysis and cleaning the data and importing it to MonoDb.

# %%
import xml.etree.ElementTree as ET

node = 0
way = 0
relation = 0
tags = 0
for even,elem in ET.iterparse('Hyderabad_part.osm'): 
    if elem.tag == 'node':
        node += 1
        tag_list = elem.findall('tag')
        tags += len(tag_list)
    if elem.tag == 'way':
        way += 1
    if elem.tag == 'relation':
        relation += 1
print("no of nodes ", node, "\n", "no of 'tag's within nodes ", tags,  "\n", "no of ways ", way, "\n", "no of relations ", relation)
# Out:
# no of nodes  397179
#  no of 'tag's within nodes  5174
#  no of ways  93328
#  no of relations  626

# %% [markdown]
# The above statistics show us how many nodes, 'tag' elements within nodes, ways and relations are present in our sample data of Hyderbad.

# %%
# let us take a look at number of unique users

unique_id = set()
for even,elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way' or elem.tag == 'relation':
        unique_id.add(elem.attrib['uid'])
len(unique_id)
# Out:
# 397

# %% [markdown]
# A total of 397 users have contributed to this part of map.

# %% [markdown]
# ## Familiarising with Data Set

# %% [markdown]
# Lets go through the 'tag's, children of 'node' and get the unique values of 'k' attributes, to get a glimpse of this data.

# %%
#get unique values of 'k' attributes under each 'node'


k_set = set() # empty set to collect all the unique values of 'k'
for even,elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way' or elem.tag == 'relation':
        tag_list = elem.findall('tag')
        for tag in tag_list:
            k_set.add(tag.attrib['k'])
print(k_set)
# Out:
# {'oneway', 'surface', 'removed:amenity', 'id', 'atm', 'agricultural', 'AND_a_nosr_r', 'health_facility:type', 'amenity', 'population', 'fuel:cng', 'restrictions', 'gauge', 'fuel:octane_91', 'direction', 'branch', 'contact:website', 'fixme', 'craft', 'denomination', 'height', 'fuel:diesel', 'platforms', 'parking:lane:both', 'type', 'wikipedia', 'wheelchair', 'internet_access:ssid', 'ref', 'operator', 'local_ref', 'name:ru', 'horse', 'shop', 'name', 'full_id', 'goods', 'old_name', 'maxspeed', 'leisure', 'lit', 'internet_access', 'cycleway', 'material', 'usage', 'name:ja', 'phone', 'ref_old', 'power', 'alt_name', 'traffic_calming', 'junction', 'religion', 'smoking', 'lanes', 'opening_hours', 'fee', 'historic', 'level', 'phone_1', 'country', 'train', 'cables', 'motor_vehicle', 'name:ta', 'created_by', 'layer', 'name:mr', 'supervised', 'barrier', 'end_date', 'sport', 'Temple', 'construction', 'ref:old', 'waterway', 'diet:vegetarian', 'disused', 'source', 'start_date', 'building', 'voltage', 'landuse', 'sidewalk', 'emergency', 'icao', 'int_name', 'tower:type', 'backrest', 'tunnel', 'smoothness', 'capacity', 'wifi', 'iata', 'incline', 'office', 'mahesh', 'area', 'restriction', 'cuisine', 'addr:postcode', 'passenger_lines', 'aerodrome:type', 'place', 'name:uk', 'removed:shop', 'website', 'takeaway', 'name:hi', 'apartment', 'wetland', 'url:broken', 'admin_level', 'bicycle', 'check_date', 'description', 'dispensing', 'route', 'foot', 'locality', 'osm_type', 'handrail', 'payment:bitcoin', 'water_tank:volume', 'intermittent', 'electrified', 'wikipedia:hi', 'frequency', 'addr:housenumber', 'entrance', 'tourism', 'addr:street', 'shelter', 'embankment', 'service', 'internet_access:fee', 'overtaking', 'artwork_type', 'osm_id', 'motorcar', 'addr:country', 'apartments', 'network', 'name:en', 'wikidata', 'name:te', 'ele', 'stars', 'email', 'addr:city', 'note', 'rooms', 'subdenomination', 'brand', 'access', 'fuel:petrol', 'bridge', 'addr:place', 'phone_2', 'crossing', 'noexit', 'man_made', 'opening_date', 'hgv', 'int_ref', 'railway', 'organic', 'name:ur', 'network:old', 'name_1', 'addr:housename', 'motorroad', 'public_transport', 'aeroway', 'AND:importance_level', 'water', 'designation', 'natural', 'name:kn', 'highway', 'building:levels'}

# %% [markdown]
# If we look at those unique set of values of attribute 'k', we can see some of the values like 'mahesh' ( name of a person ), 'fixme' are looking quite problemating to me, so lets go though those tags and see the values of other attributes and what we can do about them.

# %% [markdown]
# ## Problems Encountered in the Data Set

# %%
# go through each problemating tag and print corresponding values of 'v' attributes

for even, elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way' or elem.tag == 'relation':
        tag_list = elem.findall('tag')
        for tag in tag_list:
            if tag.attrib['k'] == 'mahesh' or tag.attrib['k'] == 'fixme' :
                print( tag.attrib['k'], " ", tag.attrib['v'])
# Out:
# fixme   check connection
# fixme   check connection
# fixme   name
# fixme   I don't think this is a railway crossing.
# mahesh   Mahesh Kumar
# fixme   Please disconnect from highway
# fixme   This is out of place
# fixme   check connection
# fixme   check connection
# fixme   add correct type of hospital
# fixme   precise location and aa a mosq
# fixme   precise tag
# fixme   It's a courier service shop. Put an appropriate category of labels.
# fixme   check_highway_type
# fixme   Is this the outline of a building or the outline of the area which the station occupies?
# fixme   check_highway_type

# %% [markdown]
# Looks like I have got some interesting work here. Lets see how we fix these and have fun !!. The 'fixme' values of attribute 'k' are those which not perfectly marked in the openstreetmap itself.
# >The fixme key allows contributors to mark objects and places that need further attention. These can be in the form of a "note to self" or request for additional mapping resources.
#
# Source : http://wiki.openstreetmap.org/wiki/Key:fixme
#
# These attributes needs to be fixed in osm data itself, which is out of scope for this project.

# %% [markdown]
# Lets take a look at the key with value 'mahesh' and see what we can do about it.

# %%
# print latitude,longitude of the node and  all the tag attributes under the node whose one of the 'k' values is 'mahesh', 
# to figure out what that node represents


for even, elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way':
        tag_list = elem.findall('tag')
        for tag in tag_list:      
            if tag.attrib['k'] == 'mahesh' :
                tags_mahesh_node = elem.findall('tag')
                print( elem.attrib['lat'], " ", elem.attrib['lon'])
                for tag_mahesh_node in tags_mahesh_node:
                    print( tag_mahesh_node.attrib['k'], " ", tag_mahesh_node.attrib['v'])
# Out:
# 17.4319158   78.4415517
# phone   +91-9391284890
# mahesh   Mahesh Kumar
# addr:city   Hyderabad
# addr:street   Yellareddyguda Road
# addr:postcode   500073
# addr:housenumber   8-3-799/2

# %% [markdown]
# This is probably address of person named 'Mahesh Kumar', so instead the value of the 'key' to be 'mahesh', it would be appropriate if it has the tag 'name'. Let us take care of this during our data injection into MongoDb.

# %%
# take a look at all the postal code to make sure they are valid 

for even,elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way':
        tag_list = elem.findall('tag')
        for tag in tag_list:      
            if tag.attrib['k'] == 'addr:postcode':
                print(tag.attrib['v'])
# Out:
# 500038
# 500044
# 500081
# 500034
# 500082
# 500034
# 500082
# 500082
# 500082
# 500 095
# 500044
# 500028
# 500028
# 500028
# 500028
# 500028
# 500028
# 500028
# 500028
# 500028
# 500028
# 500028
# 500073
# 500029
# 500038
# 500038
# 500038
# 500038
# 500016
# 500001
# 500034
# 500029
# 500082
# 500082
# 500082
# 500082
# 500082
# 500082
# 500082
# 500082
# 500082
# 500003
# 500003
# 500016
# 500082
# 500016
# 500082
# 500027
# 500027
# 500057
# 500082
# 500053
# 500003
# 500062
# 500013
# 500057
# 500034
# 500034
# 500034
# 500082
# 500082
# 500034
# 500016
# 500001
# 500037
# 500082
# 500034
# 500016
# 500016
# 500034
# 500034
# 500063
# 500003
# 500034
# 500016
# 500016
# 500034
# 500082
# 500034
# 500016
# 500057
# 500029
# 500029
# 500026
# 500001
# 500001
# 500034
# 500038
# 500082
# 500034
# 500018
# 500038
# 500082
# 500038
# 500003
# 500003
# 500003
# 500003
# 500003
# 500029
# 500029
# 500029
# 500029
# 500029
# 500029
# 500034
# 500016
# 500016
# 500003
# 500038
# 500073
# 500073
# 500044
# 500026
# 500027
# 500082
# 500082
# 500082
# 500025
# 500016
# 500082
# 500003
# 500003
# 500003
# 500003
# 500082
# 500038
# 500082
# 500002
# 500002
# 500016
# 500001
# 500057
# 500028
# 500001
# 500016
# 500020
# 500003
# 500003
# 500003
# 500038
# 500034
# 500003
# 500080

# %% [markdown]
# Except one value, where a space included as a separator between 3 numbers. So before inserting into database, let us make sure we remove space for one such value of postcode.

# %%
# now let us audit the street names
# there are lot less values of 'tag' elements and even lot less of them have 'addr:street' in it 

import re
import collections
import pprint

expected = ['Road', 'Avenue', 'Colony', 'Lane', 'Nagar']

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

street_types = collections.defaultdict(set)

def is_street(attrib):
    return attrib == 'addr:street'

def audit_type(street_types, street):
    match = street_type_re.search(street)
    if match:
        street_type = match.group()
        if street_type not in expected:
            street_types[street_type].add(street)
    
for even,elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way':
        tag_list = elem.findall('tag')
        for tag in tag_list:
            k_value = tag.attrib['k']
            if is_street(k_value):
                audit_type(street_types, tag.attrib['v'])
                
pprint.pprint(street_types)
# Out:
# defaultdict(<class 'set'>,
#             {'1': {'Quena Square, Banjara Hills Road No. 1',
#                    'lane number 1',
#                    'street number 1'},
#              '10': {'Street No. 10'},
#              '12': {'Road No. 12'},
#              '3': {'Banjarahiils, Rd. No. 3',
#                    'Road No 3',
#                    'Siddartha Nagar Road number 3'},
#              '4': {'Roas No. 4', '4'},
#              'Abids': {'Abids'},
#              'Amderpet': {'Amderpet'},
#              'Ameerpet': {'Ameerpet'},
#              'Balkampet': {'Balkampet'},
#              'Balkumpet': {'Balkumpet'},
#              'Barkatpura': {'Barkatpura'},
#              'Bd': {'Soldier Bd'},
#              'Begumpet': {'1st Floor,Legend Apartments, Motilal Nehru Marg, '
#                           'Begumpet',
#                           'Boorugu Vihar, Begumpet',
#                           'Kundanbagh, Begumpet',
#                           'Naik Estate, Begumpet',
#                           'Nishat Bagh Colony Road, Begumpet',
#                           'Srinivas Naik Estate, Street No 1, Begumpet'},
#              'Begumpet,': {'Kundanbagh, Begumpet,'},
#              'Church': {'Harinagar Main Road,  Marinatha Church'},
#              'Domalguda': {'Gaganmahal Road, Domalguda',
#                            'Street No. 10, Domalguda'},
#              'Erragadda': {'Erragadda'},
#              'Estate': {'Khan Lateefkhan Estate'},
#              'Flyover': {'Airport Flyover', 'Punjagutta Flyover'},
#              'Galli': {'Gujarati Galli'},
#              'Gardens': {'Chikoti Gardens'},
#              'Greenlands': {'Greenlands'},
#              'Gudimalkapur': {'Ushodaya Colony, Gudimalkapur'},
#              'Hills': {', Road No 11, Lake Valley Residential Society, Banjara '
#                        'Hills',
#                        ',Valley View Apartments, Banjara Hills',
#                        'Durga Enclave, Road No 12, Banjara Hills',
#                        'Lake Valley Residential Society, Banjara Hills',
#                        'Mithilanagar Colony, Banjara Hills',
#                        'Park Enclave, Road No 12, Banjara Hills',
#                        'Road No-11, Banjara Hills',
#                        'Road No11, Banjara Hills',
#                        'Venkata Ramana Colony, Banjara Hills',
#                        'Vinayagar Mangalagiri Apartments, Road Number 10, '
#                        'Avenue 4, Banjara Hills'},
#              'Hills,': {'road no 1, Banjara Hills,'},
#              'Hospital': {'Minister Road, kims Hospital'},
#              'Marg': {'Raja Reddy Marg'},
#              'Mehdipatnam': {'Groundfloor, Priya Colony, Gudimalkapur, '
#                              'Mehdipatnam'},
#              'Mehedipatmam': {'Opp to Sai baba temple, Gudimalkapur '
#                               'crossroads, Mehedipatmam'},
#              'Mehedipatnam': {'First Floor, Opp Sai Baba Temple, GudiMalkapur '
#                               'Rd, Gudi Malkapur, Mehedipatnam',
#                               'Gudimalkapur Rd, Mehedipatnam',
#                               'Gudimalkapur, Mehedipatnam',
#                               'Inside Shivalayam temple, Gudimalkapur, '
#                               'Mehedipatnam',
#                               'Priya Colony, Gudimalkapur, Mehedipatnam',
#                               'Sai Baba Temple, Gudimalkapur, Mehedipatnam'},
#              'NALLAKUNTA,AMBERPET': {'NEW NALLAKUNTA,AMBERPET'},
#              'No.3': {'Adikmet, Road No.3'},
#              'No.7': {'Domalguda, Gaganmahal Road No.7'},
#              'Office': {'Foreigners Regional Registration Office'},
#              'Panjagutta': {', Green Land Road, Panjagutta'},
#              'Paradise': {'Paradise'},
#              'Ramnagar.': {'Ramnagar road, Ramnagar.'},
#              'Rd': {'Sardar Patel Rd'},
#              'Road,AMBERPET': {'Nallakunta Road,AMBERPET',
#                                'Shivam Road,AMBERPET'},
#              'S.R.Nagar': {'S.R.Nagar'},
#              'Secunderabad,': {'2, Sarojini Devi Rd, Regimental Bazaar, '
#                                'Shivaji Nagar, Ranga Reddy,, Secunderabad,'},
#              'Somajiguda': {'Raj Bhavan Road, Somajiguda',
#                             'Soldier Bd, Somajiguda'},
#              'Street': {'Ramalayam Street'},
#              'Telangana': {'Drnayanthi Chamber, Adarsh Nagar, Adarsh Nagar, '
#                            'Hyderabad, Telangana',
#                            'P.V.R. Hi-Tech School Building, Bansilalpet, '
#                            'Gandhinagar,, Secunderabad, Bansilalpet, Bhoiguda, '
#                            'hyderabad, Telangana'},
#              'Vidyanagar.': {'Adikmet Road, Vidyanagar.'},
#              'ameerpet': {'big bazar lane, ameerpet'},
#              'circle': {'vijaynagar colony circle', 'ameerpet circle'},
#              'colony': {'kamalapuri colony, srinagar colony',
#                         'panjagutta colony',
#                         'songwriters colony'},
#              'hills': {'banjara hills'},
#              'lane': {'Red rose restaurant lane',
#                       'maskan, Civil supplies bhavan lane'},
#              'nilayam': {'vani nilayam'},
#              'rd': {'picket rd', 'bk guda rd'},
#              'road': {'6 number road',
#                       'Abids road',
#                       'Gandhinagar road',
#                       'Indira park road',
#                       'Sbiicm road',
#                       'gandhi nagar road',
#                       'nampally to mallapally road',
#                       'vijaynagar colony road'},
#              'school': {'raimathnagar,yusufguda,near  government high school'},
#              'somajiguda': {'civil supplies bhavan lane, somajiguda'}})

# %% [markdown]
# By observing these values, we can see that there are values where actually street names don't end with street_types, they are ending with either locality name or there's a case where it ended with state name!! These are the cases where a different 'key' value should be given or rather they should be brokendown to different key values, something which is also out of scope for this project. <br>
# Let us make following changes
#
# Rd (or) Rd. (or) rd -> Road <br>
#
# Lets also make the changes below to remove incosistencies <br>
# number (or) Number ( or ) No -> No.
#
# There's also Soldier Bd, Somajiguda, where Bd refers to Board( this is the city in which I live, so I got this info from friends ).
# So let us also change this for better understanding.
#
# Bd - Board
#
# And coming to those street types, which don't end wih the expected street types, there is no need to handle them separately, as they are more common in India and most of the streets have no names. They are identified by schools or any landmarks.
#
# There are even flyovers
# which are mapped within the addr:street tag.
#
# 'Flyover': {'Punjagutta Flyover', 'Airport Flyover'}
#
# These need to be reported to osm to look into the issue, whether this is allowed or not. As of now we are not going to map these under 'street' in our MongoDb data.

# %%
# take a look at those nodes where street name contain 'flyover' :

for even,elem in ET.iterparse('Hyderabad_part.osm'):
    if elem.tag == 'node' or elem.tag == 'way':
        tag_list = elem.findall('tag')
        for tag in tag_list:      
            if tag.attrib['k'] == 'addr:street':
                if tag.attrib['v'].find('Flyover') != -1 :
                    tags_flyover_node = elem.findall('tag')
                    print( elem.attrib['lat'], " ", elem.attrib['lon'])
                    for tag_flyover_node in tags_flyover_node:
                        print( tag_flyover_node.attrib['k'], ":", tag_flyover_node.attrib['v'])
# Out:
# 17.4262464   78.4511365
# name : Himalaya Book World
# shop : books
# addr:city : hyderabad
# addr:street : Punjagutta Flyover
# 17.4440522   78.4691906
# addr:street : Airport Flyover
# amenity : cafe
# name : HeartCup Coffee

# %% [markdown]
# So by looking at above nodes, we can see that they are bookstore and a cafe. Flyover are nearer to them and those mapped these nodes, gave street names as these flyover names. As for this project is concerned, I am going to proceed with same, atleast someone can find these shops with the given information. But I am going to report this is osm, to check for further improvement of the map.

# %%
# a mapping to improve street names during data injection into MongoDb

mapping = {'Rd' : 'Road',
           'Rd.' : 'Road',
           'rd' : 'Road',
           'rd.' : 'Road',
           'number' : 'No.',
           'Number' : 'No.',
           'Bd' : 'Board'}

# %% [markdown]
# Let us use the following data model to inject the osm data into MongoDb

# %%
'''
{
"id": "",     
"type: "",
"visible":"",
"created": {
          "version":"",
          "changeset":"",
          "timestamp":"",
          "user":"",
          "uid":""
        },
"pos": [,],
"address": {
          "housenumber": "",
          "postcode": "",
          "street": ""
        },
"amenity": "",
"cuisine": "",
"name": "",
"phone": ""
}'''

''' Data Model for MongoDb '''
# Out:
# ' Data Model for MongoDb '

# %%
# function to process street names and return the corrected street name

def process_street(street, mapping):
    match = street_type_re.search(street)
    if match:                      # to make sure, we don't replace occurences in other street names
        street_type = match.group()
        if street_type == 'Telangana':  # if name of the state is found, strip if off
            street = street.replace('Telangana','');
            street = street.strip();   # to strip any unwanted spaces
            street = street.rstrip();  # to strip any commas
        for key, value in mapping.items():
            if key in street :
                street = street.replace(key,value)
                break  
        
    return street

# %%
def process_postcode(postcode):
    if len(postcode) == 6:
        postcode = int(postcode)
    elif len(postcode) == 7:
        postcode = postcode.replace(" ","")
        postcode = int(postcode)
    return postcode

# %%
CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def shape_element(element):
    node = {}
    node['created'] = {}
    node['pos'] = []
    node_addr = {}
    node_ref = []
    if element.tag == "node" or element.tag == "way" :
        node['type'] = element.tag
        if 'id' in element.attrib.keys():
            node['id'] = element.attrib['id']
        if 'visible' in element.attrib.keys():
            node['visible'] = element.attrib['visible']
        if 'lat' in element.attrib.keys():
            node['pos'].append(float(element.attrib['lat']))
        if 'lon' in element.attrib.keys():
            node['pos'].append(float(element.attrib['lon']))
        for create in CREATED:
            if create in element.attrib.keys():
                node['created'][create] = element.attrib[create]
        for tag in element.iter("tag"):
            if problemchars.search(tag.attrib['k']):
                continue
            if tag.attrib['k'] == "mahesh":     # this is just for one tag, where address of person 'mahesh' is being stored
                node_addr["name"] = tag.attrib['v']
            if tag.attrib['k'] == "addr:housenumber":
                node_addr["housenumber"] = tag.attrib['v']
            if tag.attrib['k'] == "addr:postcode":
                node_addr["postcode"] = process_postcode(tag.attrib['v'])
            if tag.attrib['k'] == "addr:street":
                node_addr["street"] = process_street(tag.attrib['v'],mapping)
            if tag.attrib['k'] == 'amenity':
                node['amenity'] = tag.attrib['v']
            if tag.attrib['k'] == 'name':
                node['name'] = tag.attrib['v']
            if tag.attrib['k'] == 'phone':
                node['phone'] = tag.attrib['v']
        if node_addr != {}:
            node['address'] = node_addr
        for nd in element.iter('nd'):
            node_ref.append(nd.attrib['ref'])
        if node_ref != []:
            node['node_refs'] = node_ref
                
        return node
    else:
        return None

# %% [markdown]
# ## Importing to MongoDb

# %%
import codecs
import json

# write each document as a line to a json file, using the same code provided in lesson 6 problem

def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")

                    
    return data

# %%
# 

from pymongo import MongoClient

process_map('Hyderabad_part.osm', False)
# Out:
# [{'created': {'changeset': '26587379',
#    'timestamp': '2014-11-06T07:57:18Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '7'},
#   'id': '245640524',
#   'pos': [17.3951469, 78.4338348],
#   'type': 'node'},
#  {'created': {'changeset': '26587379',
#    'timestamp': '2014-11-06T07:57:18Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '9'},
#   'id': '245640535',
#   'pos': [17.3949513, 78.4404526],
#   'type': 'node'},
#  {'created': {'changeset': '26404937',
#    'timestamp': '2014-10-29T05:13:05Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '7'},
#   'id': '245640546',
#   'pos': [17.3821322, 78.493346],
#   'type': 'node'},
#  {'created': {'changeset': '40860317',
#    'timestamp': '2016-07-19T14:44:10Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '245640551',
#   'pos': [17.4025469, 78.4522029],
#   'type': 'node'},
#  {'created': {'changeset': '41212863',
#    'timestamp': '2016-08-03T11:59:06Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '245640568',
#   'pos': [17.3912948, 78.5110462],
#   'type': 'node'},
#  {'created': {'changeset': '15186640',
#    'timestamp': '2013-02-27T15:48:04Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '6'},
#   'id': '245640570',
#   'pos': [17.403707, 78.4560426],
#   'type': 'node'},
#  {'created': {'changeset': '27192344',
#    'timestamp': '2014-12-03T03:00:02Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '245640573',
#   'pos': [17.3918041, 78.5141761],
#   'type': 'node'},
#  {'created': {'changeset': '17409904',
#    'timestamp': '2013-08-19T11:51:26Z',
#    'uid': '579990',
#    'user': 'vaandor',
#    'version': '8'},
#   'id': '245640730',
#   'pos': [17.4510766, 78.4363796],
#   'type': 'node'},
#  {'created': {'changeset': '27658227',
#    'timestamp': '2014-12-23T19:42:53Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '268427094',
#   'pos': [17.4164988, 78.4666329],
#   'type': 'node'},
#  {'created': {'changeset': '635779',
#    'timestamp': '2008-10-30T18:07:09Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '3'},
#   'id': '277246024',
#   'pos': [17.4499932, 78.4669651],
#   'type': 'node'},
#  {'created': {'changeset': '635779',
#    'timestamp': '2008-10-30T18:16:38Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '3'},
#   'id': '277246025',
#   'pos': [17.4514407, 78.4668952],
#   'type': 'node'},
#  {'created': {'changeset': '635779',
#    'timestamp': '2008-10-30T18:07:09Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '2'},
#   'id': '277246026',
#   'pos': [17.4516359, 78.472694],
#   'type': 'node'},
#  {'created': {'changeset': '635779',
#    'timestamp': '2008-10-30T18:07:09Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '3'},
#   'id': '277246027',
#   'pos': [17.4500346, 78.4730416],
#   'type': 'node'},
#  {'created': {'changeset': '12926126',
#    'timestamp': '2012-08-31T04:51:00Z',
#    'uid': '100487',
#    'user': 'pavithrans',
#    'version': '3'},
#   'id': '289413334',
#   'pos': [17.4354545, 78.4738567],
#   'type': 'node'},
#  {'created': {'changeset': '15305563',
#    'timestamp': '2013-03-09T17:59:16Z',
#    'uid': '112975',
#    'user': 'capiscuas',
#    'version': '5'},
#   'id': '289414251',
#   'pos': [17.4154396, 78.4660929],
#   'type': 'node'},
#  {'created': {'changeset': '39265230',
#    'timestamp': '2016-05-12T12:01:20Z',
#    'uid': '2897134',
#    'user': 'Naresh08',
#    'version': '5'},
#   'id': '289414252',
#   'pos': [17.4150471, 78.4661765],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:39Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289414462',
#   'pos': [17.4157217, 78.4661686],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:51Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289414463',
#   'pos': [17.4162049, 78.4662329],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:51Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289414465',
#   'pos': [17.4168953, 78.465925],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:50Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289414470',
#   'pos': [17.4187018, 78.4652536],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:38Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289414475',
#   'pos': [17.4223874, 78.4650846],
#   'type': 'node'},
#  {'created': {'changeset': '39265230',
#    'timestamp': '2016-05-12T12:01:20Z',
#    'uid': '2897134',
#    'user': 'Naresh08',
#    'version': '4'},
#   'id': '289414477',
#   'pos': [17.4231922, 78.4646949],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:39Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289414478',
#   'pos': [17.4235751, 78.4642225],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:52Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289414479',
#   'pos': [17.423729, 78.4637563],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:52Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289414480',
#   'pos': [17.4239884, 78.4633542],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:40Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289414482',
#   'pos': [17.4246365, 78.4629006],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:40Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289416526',
#   'pos': [17.4375027, 78.4700972],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:40Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289416675',
#   'pos': [17.4165012, 78.4661655],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:41Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289416676',
#   'pos': [17.4172501, 78.4656295],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:53Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289416677',
#   'pos': [17.4175816, 78.4653676],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:39Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289416678',
#   'pos': [17.4178269, 78.4652509],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:39Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289416679',
#   'pos': [17.418329, 78.465202],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:51Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289416680',
#   'pos': [17.4196571, 78.4654156],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:51Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289416682',
#   'pos': [17.4201848, 78.465356],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:52Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289416683',
#   'pos': [17.4209504, 78.4652453],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:52Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289416684',
#   'pos': [17.4218044, 78.4651415],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:38Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289416686',
#   'pos': [17.4243625, 78.4629989],
#   'type': 'node'},
#  {'created': {'changeset': '12757687',
#    'timestamp': '2012-08-17T04:02:39Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289416693',
#   'pos': [17.4373109, 78.4691607],
#   'type': 'node'},
#  {'created': {'changeset': '643984',
#    'timestamp': '2008-10-31T17:37:02Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '2'},
#   'id': '289416706',
#   'pos': [17.432691, 78.4845791],
#   'type': 'node'},
#  {'created': {'changeset': '11673763',
#    'timestamp': '2012-05-22T17:40:47Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289505867',
#   'pos': [17.4151073, 78.4648675],
#   'type': 'node'},
#  {'created': {'changeset': '11673763',
#    'timestamp': '2012-05-22T17:40:47Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289509618',
#   'pos': [17.4158627, 78.4615851],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289509619',
#   'pos': [17.4157427, 78.4612506],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289509620',
#   'pos': [17.4156375, 78.4610979],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289509621',
#   'pos': [17.4154078, 78.460907],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '8'},
#   'id': '289509856',
#   'pos': [17.4287668, 78.4554611],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '289509857',
#   'pos': [17.428513, 78.455859],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:29:43Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509859',
#   'pos': [17.427999, 78.4567793],
#   'type': 'node'},
#  {'created': {'changeset': '26385541',
#    'timestamp': '2014-10-28T11:43:19Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509860',
#   'pos': [17.4278655, 78.4569212],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:29:42Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509861',
#   'pos': [17.4273346, 78.4573661],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:29:41Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509862',
#   'pos': [17.4271353, 78.4574441],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:29:41Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509863',
#   'pos': [17.4269247, 78.4574367],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509864',
#   'pos': [17.426239, 78.4571187],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509865',
#   'pos': [17.4258033, 78.4570923],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:29:42Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509866',
#   'pos': [17.4252818, 78.4571638],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509868',
#   'pos': [17.4244124, 78.4575046],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '7'},
#   'id': '289509869',
#   'pos': [17.4239012, 78.4580551],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:18:18Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509870',
#   'pos': [17.423732, 78.4583989],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509871',
#   'pos': [17.4235461, 78.4588491],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:18:18Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509872',
#   'pos': [17.4233757, 78.4594494],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509875',
#   'pos': [17.4229486, 78.461762],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:58Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '7'},
#   'id': '289509876',
#   'pos': [17.4228518, 78.4620286],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:18:18Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '6'},
#   'id': '289509878',
#   'pos': [17.4223321, 78.4625914],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:18:18Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '7'},
#   'id': '289509879',
#   'pos': [17.4221432, 78.4626724],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:18:18Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '8'},
#   'id': '289509880',
#   'pos': [17.4218733, 78.4626384],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:58Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289509881',
#   'pos': [17.4214392, 78.4625393],
#   'type': 'node'},
#  {'created': {'changeset': '11608861',
#    'timestamp': '2012-05-15T21:06:56Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509884',
#   'pos': [17.4160292, 78.4607971],
#   'type': 'node'},
#  {'created': {'changeset': '11608861',
#    'timestamp': '2012-05-15T21:06:56Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289509885',
#   'pos': [17.4147893, 78.4603745],
#   'type': 'node'},
#  {'created': {'changeset': '11674524',
#    'timestamp': '2012-05-22T19:05:35Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '8'},
#   'id': '289509886',
#   'pos': [17.4137527, 78.4599837],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '7'},
#   'id': '289510308',
#   'pos': [17.4385506, 78.4570583],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '33'},
#   'id': '289510334',
#   'pos': [17.4289095, 78.4554088],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '20'},
#   'id': '289510337',
#   'pos': [17.4287975, 78.4551203],
#   'type': 'node'},
#  {'created': {'changeset': '11608861',
#    'timestamp': '2012-05-15T20:48:17Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '19'},
#   'id': '289510338',
#   'pos': [17.4285586, 78.4541616],
#   'type': 'node'},
#  {'created': {'changeset': '27016607',
#    'timestamp': '2014-11-25T08:56:37Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '20'},
#   'id': '289510340',
#   'pos': [17.4281482, 78.4533031],
#   'type': 'node'},
#  {'created': {'changeset': '36850548',
#    'timestamp': '2016-01-28T05:45:33Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '21'},
#   'id': '289510342',
#   'pos': [17.4271901, 78.4527965],
#   'type': 'node'},
#  {'created': {'changeset': '15192477',
#    'timestamp': '2013-02-28T04:53:43Z',
#    'uid': '1127874',
#    'user': 'Pravi',
#    'version': '20'},
#   'id': '289510345',
#   'pos': [17.4269583, 78.4526809],
#   'type': 'node'},
#  {'created': {'changeset': '27016607',
#    'timestamp': '2014-11-25T08:56:37Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '12'},
#   'id': '289510346',
#   'pos': [17.4271038, 78.4522925],
#   'type': 'node'},
#  {'created': {'changeset': '11599134',
#    'timestamp': '2012-05-14T19:50:51Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '9'},
#   'id': '289511418',
#   'pos': [17.4368966, 78.4439487],
#   'type': 'node'},
#  {'created': {'changeset': '26384252',
#    'timestamp': '2014-10-28T10:35:50Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '9'},
#   'id': '289511426',
#   'pos': [17.4340945, 78.445759],
#   'type': 'node'},
#  {'created': {'changeset': '11608861',
#    'timestamp': '2012-05-15T21:01:07Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289511452',
#   'pos': [17.4131877, 78.460246],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289511453',
#   'pos': [17.41247, 78.4605259],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:36Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '6'},
#   'id': '289511455',
#   'pos': [17.411702, 78.4607866],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:36Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289511463',
#   'pos': [17.4091822, 78.4605191],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:36Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '9'},
#   'id': '289511466',
#   'pos': [17.4075271, 78.4604995],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289511804',
#   'pos': [17.4149894, 78.4607766],
#   'type': 'node'},
#  {'created': {'changeset': '11673763',
#    'timestamp': '2012-05-22T17:40:47Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289511805',
#   'pos': [17.4139789, 78.4607738],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:36Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '6'},
#   'id': '289511807',
#   'pos': [17.4134824, 78.4604386],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:33:55Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '20'},
#   'id': '289512364',
#   'pos': [17.4348605, 78.455388],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '20'},
#   'id': '289512371',
#   'pos': [17.4313347, 78.456097],
#   'type': 'node'},
#  {'created': {'changeset': '39262802',
#    'timestamp': '2016-05-12T10:05:09Z',
#    'uid': '2897134',
#    'user': 'Naresh08',
#    'version': '23'},
#   'id': '289512382',
#   'pos': [17.426559, 78.4520786],
#   'type': 'node'},
#  {'created': {'changeset': '26542589',
#    'timestamp': '2014-11-04T07:34:30Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '8'},
#   'id': '289513470',
#   'name': 'Road no.1/10',
#   'pos': [17.4149819, 78.4500201],
#   'type': 'node'},
#  {'created': {'changeset': '26542589',
#    'timestamp': '2014-11-04T07:34:30Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '9'},
#   'id': '289513492',
#   'name': 'Taj Krishna Jn',
#   'pos': [17.4171519, 78.4490002],
#   'type': 'node'},
#  {'created': {'changeset': '40860317',
#    'timestamp': '2016-07-19T14:44:10Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '9'},
#   'id': '289513516',
#   'pos': [17.4199514, 78.4478278],
#   'type': 'node'},
#  {'created': {'changeset': '40860317',
#    'timestamp': '2016-07-19T14:44:10Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '10'},
#   'id': '289513519',
#   'pos': [17.420071, 78.4478689],
#   'type': 'node'},
#  {'created': {'changeset': '19577932',
#    'timestamp': '2013-12-22T08:58:03Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '11'},
#   'id': '289515402',
#   'pos': [17.4261786, 78.447483],
#   'type': 'node'},
#  {'created': {'changeset': '762618',
#    'timestamp': '2008-11-17T19:40:21Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '3'},
#   'id': '289517950',
#   'pos': [17.4209221, 78.4376214],
#   'type': 'node'},
#  {'created': {'changeset': '39282047',
#    'timestamp': '2016-05-13T04:58:42Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '5'},
#   'id': '289517955',
#   'pos': [17.4209161, 78.4393447],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:33:55Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '21'},
#   'id': '289519019',
#   'pos': [17.4356397, 78.455646],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:33:55Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '20'},
#   'id': '289519020',
#   'pos': [17.4342252, 78.4554769],
#   'type': 'node'},
#  {'created': {'changeset': '40918930',
#    'timestamp': '2016-07-21T12:30:26Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '20'},
#   'id': '289519022',
#   'pos': [17.4325996, 78.4560544],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:34Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '24'},
#   'id': '289519025',
#   'pos': [17.4290662, 78.4555843],
#   'type': 'node'},
#  {'created': {'changeset': '11608861',
#    'timestamp': '2012-05-15T20:48:17Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '19'},
#   'id': '289519026',
#   'pos': [17.4277279, 78.4530494],
#   'type': 'node'},
#  {'created': {'changeset': '39391142',
#    'timestamp': '2016-05-18T05:00:28Z',
#    'uid': '2901758',
#    'user': 'anthony1',
#    'version': '6'},
#   'id': '289519334',
#   'pos': [17.436951, 78.4565788],
#   'type': 'node'},
#  {'created': {'changeset': '26384827',
#    'timestamp': '2014-10-28T11:07:57Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289520169',
#   'pos': [17.4296982, 78.4504632],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '6'},
#   'id': '289520180',
#   'pos': [17.4104667, 78.4609313],
#   'type': 'node'},
#  {'created': {'changeset': '17181037',
#    'timestamp': '2013-08-01T15:15:44Z',
#    'uid': '179403',
#    'user': 'వీవెన్',
#    'version': '10'},
#   'id': '289520248',
#   'pos': [17.4345554, 78.4485203],
#   'type': 'node'},
#  {'created': {'changeset': '17181037',
#    'timestamp': '2013-08-01T15:15:44Z',
#    'uid': '179403',
#    'user': 'వీవెన్',
#    'version': '9'},
#   'id': '289520250',
#   'pos': [17.4347459, 78.4496987],
#   'type': 'node'},
#  {'created': {'changeset': '12863471',
#    'timestamp': '2012-08-26T09:11:12Z',
#    'uid': '826532',
#    'user': 'NiteshSingh',
#    'version': '7'},
#   'id': '289520252',
#   'pos': [17.4350053, 78.4509835],
#   'type': 'node'},
#  {'created': {'changeset': '13380400',
#    'timestamp': '2012-10-06T04:00:28Z',
#    'uid': '934114',
#    'user': 'Kalyan_maverick',
#    'version': '8'},
#   'id': '289520254',
#   'pos': [17.4351836, 78.4515034],
#   'type': 'node'},
#  {'created': {'changeset': '39376286',
#    'timestamp': '2016-05-17T13:01:59Z',
#    'uid': '2901758',
#    'user': 'anthony1',
#    'version': '10'},
#   'id': '289520256',
#   'pos': [17.4361457, 78.4525144],
#   'type': 'node'},
#  {'created': {'changeset': '13380400',
#    'timestamp': '2012-10-06T03:56:51Z',
#    'uid': '934114',
#    'user': 'Kalyan_maverick',
#    'version': '7'},
#   'id': '289520258',
#   'pos': [17.4358584, 78.4539622],
#   'type': 'node'},
#  {'created': {'changeset': '17181037',
#    'timestamp': '2013-08-01T15:15:44Z',
#    'uid': '179403',
#    'user': 'వీవెన్',
#    'version': '9'},
#   'id': '289520295',
#   'pos': [17.4346045, 78.4489632],
#   'type': 'node'},
#  {'created': {'changeset': '12863471',
#    'timestamp': '2012-08-26T09:11:13Z',
#    'uid': '826532',
#    'user': 'NiteshSingh',
#    'version': '7'},
#   'id': '289520297',
#   'pos': [17.4350626, 78.4512831],
#   'type': 'node'},
#  {'created': {'changeset': '13380400',
#    'timestamp': '2012-10-06T04:00:28Z',
#    'uid': '934114',
#    'user': 'Kalyan_maverick',
#    'version': '8'},
#   'id': '289520298',
#   'pos': [17.4357982, 78.4521257],
#   'type': 'node'},
#  {'created': {'changeset': '13380400',
#    'timestamp': '2012-10-06T04:00:28Z',
#    'uid': '934114',
#    'user': 'Kalyan_maverick',
#    'version': '9'},
#   'id': '289520299',
#   'pos': [17.436123, 78.4530146],
#   'type': 'node'},
#  {'created': {'changeset': '13380400',
#    'timestamp': '2012-10-06T03:55:47Z',
#    'uid': '934114',
#    'user': 'Kalyan_maverick',
#    'version': '7'},
#   'id': '289520300',
#   'pos': [17.4355001, 78.4548347],
#   'type': 'node'},
#  {'created': {'changeset': '26384252',
#    'timestamp': '2014-10-28T10:35:50Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289520456',
#   'pos': [17.4355182, 78.4448877],
#   'type': 'node'},
#  {'created': {'changeset': '26384252',
#    'timestamp': '2014-10-28T10:35:51Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '7'},
#   'id': '289520459',
#   'pos': [17.4308669, 78.4489567],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '6'},
#   'id': '289520472',
#   'pos': [17.4120434, 78.4607209],
#   'type': 'node'},
#  {'created': {'changeset': '17181037',
#    'timestamp': '2013-08-01T15:15:44Z',
#    'uid': '179403',
#    'user': 'వీవెన్',
#    'version': '6'},
#   'id': '289520551',
#   'pos': [17.4345068, 78.4481083],
#   'type': 'node'},
#  {'created': {'changeset': '17409904',
#    'timestamp': '2013-08-19T11:51:29Z',
#    'uid': '579990',
#    'user': 'vaandor',
#    'version': '5'},
#   'id': '289520763',
#   'pos': [17.4302298, 78.4498542],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289520769',
#   'pos': [17.4095518, 78.4606143],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289520771',
#   'pos': [17.4081092, 78.4604432],
#   'type': 'node'},
#  {'created': {'changeset': '17409904',
#    'timestamp': '2013-08-19T11:51:27Z',
#    'uid': '579990',
#    'user': 'vaandor',
#    'version': '8'},
#   'id': '289521088',
#   'pos': [17.4300906, 78.4500495],
#   'type': 'node'},
#  {'created': {'changeset': '8341752',
#    'timestamp': '2011-06-04T18:57:20Z',
#    'uid': '250196',
#    'user': 'adivik2000',
#    'version': '5'},
#   'id': '289521090',
#   'pos': [17.4297769, 78.4492615],
#   'type': 'node'},
#  {'created': {'changeset': '8341752',
#    'timestamp': '2011-06-04T18:57:21Z',
#    'uid': '250196',
#    'user': 'adivik2000',
#    'version': '5'},
#   'id': '289521092',
#   'pos': [17.4296839, 78.4486018],
#   'type': 'node'},
#  {'created': {'changeset': '8341752',
#    'timestamp': '2011-06-04T18:57:21Z',
#    'uid': '250196',
#    'user': 'adivik2000',
#    'version': '5'},
#   'id': '289521093',
#   'pos': [17.4296505, 78.4480742],
#   'type': 'node'},
#  {'created': {'changeset': '33178688',
#    'timestamp': '2015-08-07T12:15:35Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '7'},
#   'id': '289521098',
#   'pos': [17.4299043, 78.446389],
#   'type': 'node'},
#  {'created': {'changeset': '32768246',
#    'timestamp': '2015-07-21T05:43:34Z',
#    'uid': '2949621',
#    'user': 'Narsimulu',
#    'version': '6'},
#   'id': '289521099',
#   'pos': [17.4299841, 78.4456777],
#   'type': 'node'},
#  {'created': {'changeset': '8341752',
#    'timestamp': '2011-06-04T18:55:32Z',
#    'uid': '250196',
#    'user': 'adivik2000',
#    'version': '5'},
#   'id': '289521101',
#   'pos': [17.430119, 78.4442503],
#   'type': 'node'},
#  {'created': {'changeset': '8341752',
#    'timestamp': '2011-06-04T19:08:34Z',
#    'uid': '250196',
#    'user': 'adivik2000',
#    'version': '5'},
#   'id': '289521502',
#   'pos': [17.4301592, 78.4423858],
#   'type': 'node'},
#  {'created': {'changeset': '39283542',
#    'timestamp': '2016-05-13T06:39:58Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '7'},
#   'id': '289521513',
#   'pos': [17.430165, 78.4399885],
#   'type': 'node'},
#  {'created': {'changeset': '11674524',
#    'timestamp': '2012-05-22T19:05:34Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '6'},
#   'id': '289522087',
#   'pos': [17.4128559, 78.4604571],
#   'type': 'node'},
#  {'created': {'changeset': '15323798',
#    'timestamp': '2013-03-11T04:58:37Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289525648',
#   'pos': [17.4101564, 78.460864],
#   'type': 'node'},
#  {'created': {'changeset': '41348536',
#    'timestamp': '2016-08-09T16:13:16Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '7'},
#   'id': '289527005',
#   'pos': [17.4070093, 78.4609921],
#   'type': 'node'},
#  {'created': {'changeset': '635779',
#    'timestamp': '2008-10-30T18:16:38Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '3'},
#   'id': '289572247',
#   'pos': [17.4515164, 78.4725305],
#   'type': 'node'},
#  {'created': {'changeset': '635779',
#    'timestamp': '2008-10-30T18:16:38Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '3'},
#   'id': '289572296',
#   'pos': [17.4514557, 78.4683458],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:52Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289582012',
#   'pos': [17.4245107, 78.4626514],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582016',
#   'pos': [17.4223651, 78.4629597],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:51Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289582021',
#   'pos': [17.417892, 78.4617276],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '4'},
#   'id': '289582023',
#   'pos': [17.4150635, 78.4611013],
#   'type': 'node'},
#  {'created': {'changeset': '46594382',
#    'timestamp': '2017-03-05T12:07:51Z',
#    'uid': '2815653',
#    'user': 'Srihari Thalla',
#    'version': '6'},
#   'id': '289582025',
#   'name': 'Khairatabad',
#   'pos': [17.4129881, 78.4611879],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582028',
#   'pos': [17.4077039, 78.4617711],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582036',
#   'pos': [17.4036974, 78.4634513],
#   'type': 'node'},
#  {'created': {'changeset': '46594382',
#    'timestamp': '2017-03-05T12:07:54Z',
#    'uid': '2815653',
#    'user': 'Srihari Thalla',
#    'version': '5'},
#   'id': '289582401',
#   'name': 'Necklace Road',
#   'pos': [17.4237342, 78.4628902],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582402',
#   'pos': [17.4220515, 78.4629074],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:52Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289582403',
#   'pos': [17.4161378, 78.4613014],
#   'type': 'node'},
#  {'created': {'changeset': '7959378',
#    'timestamp': '2011-04-25T06:06:50Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289582406',
#   'pos': [17.4105527, 78.4614503],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582410',
#   'pos': [17.4040566, 78.4631846],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582417',
#   'pos': [17.3956947, 78.4676872],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289582418',
#   'pos': [17.3950387, 78.4676647],
#   'type': 'node'},
#  {'created': {'changeset': '46221671',
#    'timestamp': '2017-02-19T17:20:51Z',
#    'uid': '2815653',
#    'user': 'Srihari Thalla',
#    'version': '4'},
#   'id': '289582419',
#   'pos': [17.3911562, 78.4672948],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '3'},
#   'id': '289585826',
#   'pos': [17.4376643, 78.4691277],
#   'type': 'node'},
#  {'created': {'changeset': '34606899',
#    'timestamp': '2015-10-13T09:26:54Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '7'},
#   'id': '289585827',
#   'pos': [17.4378171, 78.4698989],
#   'type': 'node'},
#  {'created': {'changeset': '803361',
#    'timestamp': '2009-03-13T17:46:00Z',
#    'uid': '101441',
#    'user': 'Sunil Mohan Adapa',
#    'version': '6'},
#   'id': '289585849',
#   'pos': [17.432794, 78.501275],
#   'type': 'node'},
#  {'created': {'changeset': '34575595',
#    'timestamp': '2015-10-11T18:34:48Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '5'},
#   'id': '289585850',
#   'pos': [17.4335021, 78.5041025],
#   'type': 'node'},
#  {'created': {'changeset': '44215592',
#    'timestamp': '2016-12-06T17:56:40Z',
#    'uid': '2815653',
#    'user': 'Srihari Thalla',
#    'version': '9'},
#   'id': '289656763',
#   'name': 'Hyderabad Deccan Nampally',
#   'pos': [17.3924319, 78.4674177],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '4'},
#   'id': '289658018',
#   'pos': [17.4390352, 78.457237],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '4'},
#   'id': '289658021',
#   'pos': [17.4393043, 78.4573136],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '8'},
#   'id': '289658025',
#   'pos': [17.4416592, 78.457865],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '7'},
#   'id': '289658027',
#   'pos': [17.4420814, 78.4581499],
#   'type': 'node'},
#  {'created': {'changeset': '26385541',
#    'timestamp': '2014-10-28T11:43:20Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289658034',
#   'pos': [17.4441641, 78.4610751],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '7'},
#   'id': '289658041',
#   'pos': [17.4447105, 78.4673276],
#   'type': 'node'},
#  {'created': {'changeset': '45248080',
#    'timestamp': '2017-01-17T17:15:53Z',
#    'uid': '1989621',
#    'user': 'soale',
#    'version': '6'},
#   'id': '289658042',
#   'pos': [17.444643, 78.4675435],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:54:43Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289658043',
#   'pos': [17.4441386, 78.470802],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '8'},
#   'id': '289658045',
#   'pos': [17.4441591, 78.4729319],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:57:35Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289658046',
#   'pos': [17.4439822, 78.4740444],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:57:35Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289658047',
#   'pos': [17.4437829, 78.474948],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '289658050',
#   'pos': [17.4435356, 78.4790949],
#   'type': 'node'},
#  {'created': {'changeset': '11827107',
#    'timestamp': '2012-06-07T17:22:00Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289658051',
#   'pos': [17.4435205, 78.480969],
#   'type': 'node'},
#  {'created': {'changeset': '40918930',
#    'timestamp': '2016-07-21T12:30:26Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '5'},
#   'id': '289658053',
#   'pos': [17.4434768, 78.4826371],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '289658061',
#   'pos': [17.4429082, 78.5005446],
#   'type': 'node'},
#  {'created': {'changeset': '620782',
#    'timestamp': '2008-12-26T07:09:50Z',
#    'uid': '81718',
#    'user': 'vvmanoj',
#    'version': '6'},
#   'id': '289658062',
#   'pos': [17.4428416, 78.501366],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '289658063',
#   'pos': [17.4428265, 78.5032956],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '5'},
#   'id': '289658065',
#   'pos': [17.4428163, 78.5036243],
#   'type': 'node'},
#  {'created': {'changeset': '11827384',
#    'timestamp': '2012-06-07T18:07:45Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289658066',
#   'pos': [17.4427284, 78.5040674],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '4'},
#   'id': '289658067',
#   'pos': [17.4425441, 78.5044798],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '5'},
#   'id': '289658068',
#   'pos': [17.4424868, 78.5045918],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '6'},
#   'id': '289658069',
#   'pos': [17.442513, 78.505148],
#   'type': 'node'},
#  {'created': {'changeset': '15211685',
#    'timestamp': '2013-03-01T16:21:15Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289894913',
#   'pos': [17.4245957, 78.4860849],
#   'type': 'node'},
#  {'created': {'changeset': '15211685',
#    'timestamp': '2013-03-01T16:21:15Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289894952',
#   'pos': [17.4250424, 78.4861794],
#   'type': 'node'},
#  {'created': {'changeset': '40918701',
#    'timestamp': '2016-07-21T12:19:05Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '7'},
#   'id': '289895019',
#   'pos': [17.4105505, 78.476296],
#   'type': 'node'},
#  {'created': {'changeset': '40918701',
#    'timestamp': '2016-07-21T12:19:05Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '8'},
#   'id': '289895020',
#   'pos': [17.4214129, 78.4844129],
#   'type': 'node'},
#  {'created': {'changeset': '15211685',
#    'timestamp': '2013-03-01T16:21:14Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289895021',
#   'pos': [17.4085608, 78.474892],
#   'type': 'node'},
#  {'created': {'changeset': '27649122',
#    'timestamp': '2014-12-23T11:56:09Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '289896036',
#   'pos': [17.4114358, 78.4712954],
#   'type': 'node'},
#  {'created': {'changeset': '27217449',
#    'timestamp': '2014-12-04T04:20:26Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '289896455',
#   'pos': [17.4072205, 78.4675799],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:24Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289903728',
#   'pos': [17.4064772, 78.465358],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:25Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289903729',
#   'pos': [17.4062212, 78.4650644],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:24Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289903730',
#   'pos': [17.4057781, 78.4646682],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:23Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289903833',
#   'pos': [17.4054149, 78.4643909],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:15:00Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '3'},
#   'id': '289904510',
#   'pos': [17.4070218, 78.4675164],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:15:00Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289904514',
#   'pos': [17.4070481, 78.4677221],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:15:00Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '4'},
#   'id': '289904515',
#   'pos': [17.4071739, 78.4677134],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:15:00Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '3'},
#   'id': '289904614',
#   'pos': [17.4071017, 78.4674825],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:15:00Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '3'},
#   'id': '289904616',
#   'pos': [17.4069853, 78.4676339],
#   'type': 'node'},
#  {'created': {'changeset': '15186640',
#    'timestamp': '2013-02-27T15:48:06Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289904661',
#   'pos': [17.403376, 78.4678621],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:22Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289904677',
#   'pos': [17.4051257, 78.4640964],
#   'type': 'node'},
#  {'created': {'changeset': '15186640',
#    'timestamp': '2013-02-27T15:48:05Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289904678',
#   'pos': [17.4051376, 78.4638915],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:22Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '289904732',
#   'pos': [17.4047495, 78.4642809],
#   'type': 'node'},
#  {'created': {'changeset': '27105853',
#    'timestamp': '2014-11-29T07:53:26Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '289904761',
#   'pos': [17.4051734, 78.464195],
#   'type': 'node'},
#  {'created': {'changeset': '41348536',
#    'timestamp': '2016-08-09T16:13:16Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '5'},
#   'id': '289904886',
#   'pos': [17.4067867, 78.4618085],
#   'type': 'node'},
#  {'created': {'changeset': '11823536',
#    'timestamp': '2012-06-07T10:08:02Z',
#    'uid': '282938',
#    'user': 'FlankerH',
#    'version': '5'},
#   'id': '289904887',
#   'pos': [17.4067214, 78.4621268],
#   'type': 'node'},
#  {'created': {'changeset': '41348536',
#    'timestamp': '2016-08-09T16:13:16Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '5'},
#   'id': '289904888',
#   'pos': [17.40663, 78.4624681],
#   'type': 'node'},
#  {'created': {'changeset': '15186640',
#    'timestamp': '2013-02-27T15:48:04Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '4'},
#   'id': '289904889',
#   'pos': [17.4062504, 78.4628471],
#   'type': 'node'},
#  {'created': {'changeset': '15186640',
#    'timestamp': '2013-02-27T15:48:05Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289904890',
#   'pos': [17.4054615, 78.4635739],
#   'type': 'node'},
#  {'created': {'changeset': '26588381',
#    'timestamp': '2014-11-06T09:06:23Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '289904891',
#   'pos': [17.4031552, 78.4656676],
#   'type': 'node'},
#  {'created': {'changeset': '26588381',
#    'timestamp': '2014-11-06T09:06:23Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '289904895',
#   'pos': [17.4027063, 78.4670281],
#   'type': 'node'},
#  {'created': {'changeset': '26588381',
#    'timestamp': '2014-11-06T09:06:23Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '289904896',
#   'pos': [17.4026813, 78.4672962],
#   'type': 'node'},
#  {'created': {'changeset': '15205277',
#    'timestamp': '2013-03-01T06:53:20Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289904900',
#   'pos': [17.4067574, 78.4675221],
#   'type': 'node'},
#  {'created': {'changeset': '15205277',
#    'timestamp': '2013-03-01T06:53:20Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289904902',
#   'pos': [17.4063199, 78.4673472],
#   'type': 'node'},
#  {'created': {'changeset': '26386141',
#    'timestamp': '2014-10-28T12:09:45Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '289905221',
#   'pos': [17.4237014, 78.4858707],
#   'type': 'node'},
#  {'created': {'changeset': '27536453',
#    'timestamp': '2014-12-17T18:51:42Z',
#    'uid': '2219338',
#    'user': 'RichRico',
#    'version': '12'},
#   'id': '289907074',
#   'name': 'Paradise',
#   'pos': [17.4418278, 78.4875311],
#   'type': 'node'},
#  {'created': {'changeset': '26727559',
#    'timestamp': '2014-11-12T05:37:02Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '289907934',
#   'pos': [17.4337702, 78.4852221],
#   'type': 'node'},
#  {'created': {'changeset': '40950685',
#    'timestamp': '2016-07-22T13:44:35Z',
#    'uid': '1016290',
#    'user': 'Amaroussi',
#    'version': '8'},
#   'id': '289908627',
#   'pos': [17.443796, 78.4873745],
#   'type': 'node'},
#  {'created': {'changeset': '26313685',
#    'timestamp': '2014-10-25T05:02:53Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '289908633',
#   'pos': [17.4490309, 78.4874563],
#   'type': 'node'},
#  {'created': {'changeset': '15205277',
#    'timestamp': '2013-03-01T06:53:19Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '289916810',
#   'pos': [17.4021516, 78.4687209],
#   'type': 'node'},
#  {'created': {'changeset': '26840354',
#    'timestamp': '2014-11-17T10:14:20Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '289916812',
#   'pos': [17.4017406, 78.4693357],
#   'type': 'node'},
#  {'created': {'changeset': '15186640',
#    'timestamp': '2013-02-27T15:48:05Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '289916818',
#   'pos': [17.4006251, 78.4704892],
#   'type': 'node'},
#  {'created': {'changeset': '7993053',
#    'timestamp': '2011-04-28T10:00:24Z',
# ...
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '3'},
#   'id': '308783062',
#   'pos': [17.3857607, 78.4918955],
#   'type': 'node'},
#  {'created': {'changeset': '39393465',
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '3'},
#   'id': '308783063',
#   'pos': [17.3853304, 78.4919663],
#   'type': 'node'},
#  {'created': {'changeset': '39393465',
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '4'},
#   'id': '308783064',
#   'pos': [17.3839855, 78.4917379],
#   'type': 'node'},
#  {'created': {'changeset': '32351461',
#    'timestamp': '2015-07-02T10:56:05Z',
#    'uid': '2900563',
#    'user': 'thrinath',
#    'version': '3'},
#   'id': '308783068',
#   'pos': [17.3848021, 78.4938079],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:48Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783069',
#   'pos': [17.3855165, 78.4939909],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:48Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783070',
#   'pos': [17.3862593, 78.4943457],
#   'type': 'node'},
#  {'created': {'changeset': '32974388',
#    'timestamp': '2015-07-30T09:38:10Z',
#    'uid': '2869631',
#    'user': 'Rajkumarmishra',
#    'version': '2'},
#   'id': '308783071',
#   'pos': [17.3871343, 78.4950902],
#   'type': 'node'},
#  {'created': {'changeset': '26404937',
#    'timestamp': '2014-10-29T05:13:05Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '2'},
#   'id': '308783072',
#   'pos': [17.3875812, 78.4955143],
#   'type': 'node'},
#  {'created': {'changeset': '32923448',
#    'timestamp': '2015-07-28T06:57:21Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '3'},
#   'id': '308783075',
#   'pos': [17.3890222, 78.4968753],
#   'type': 'node'},
#  {'created': {'changeset': '15336539',
#    'timestamp': '2013-03-12T07:39:18Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '308783076',
#   'pos': [17.3899155, 78.4902583],
#   'type': 'node'},
#  {'created': {'changeset': '39392811',
#    'timestamp': '2016-05-18T06:58:09Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '2'},
#   'id': '308783077',
#   'pos': [17.3895155, 78.4901892],
#   'type': 'node'},
#  {'created': {'changeset': '39392811',
#    'timestamp': '2016-05-18T06:58:09Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '3'},
#   'id': '308783080',
#   'pos': [17.3860109, 78.4900129],
#   'type': 'node'},
#  {'created': {'changeset': '32351461',
#    'timestamp': '2015-07-02T10:56:05Z',
#    'uid': '2900563',
#    'user': 'thrinath',
#    'version': '3'},
#   'id': '308783081',
#   'pos': [17.3837743, 78.4907949],
#   'type': 'node'},
#  {'created': {'changeset': '39393465',
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '4'},
#   'id': '308783082',
#   'pos': [17.3843756, 78.4926998],
#   'type': 'node'},
#  {'created': {'changeset': '32750399',
#    'timestamp': '2015-07-20T10:18:23Z',
#    'uid': '2995991',
#    'user': 'sramesh',
#    'version': '4'},
#   'id': '308783083',
#   'pos': [17.3845374, 78.4928127],
#   'type': 'node'},
#  {'created': {'changeset': '32351461',
#    'timestamp': '2015-07-02T10:56:05Z',
#    'uid': '2900563',
#    'user': 'thrinath',
#    'version': '3'},
#   'id': '308783088',
#   'pos': [17.3848049, 78.4976668],
#   'type': 'node'},
#  {'created': {'changeset': '32351461',
#    'timestamp': '2015-07-02T10:56:05Z',
#    'uid': '2900563',
#    'user': 'thrinath',
#    'version': '3'},
#   'id': '308783089',
#   'pos': [17.3846452, 78.4979961],
#   'type': 'node'},
#  {'created': {'changeset': '26404937',
#    'timestamp': '2014-10-29T05:13:05Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '2'},
#   'id': '308783090',
#   'pos': [17.3843806, 78.4905684],
#   'type': 'node'},
#  {'created': {'changeset': '39394852',
#    'timestamp': '2016-05-18T08:40:26Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '6'},
#   'id': '308783091',
#   'pos': [17.387304, 78.4934035],
#   'type': 'node'},
#  {'created': {'changeset': '32974388',
#    'timestamp': '2015-07-30T09:38:10Z',
#    'uid': '2869631',
#    'user': 'Rajkumarmishra',
#    'version': '3'},
#   'id': '308783092',
#   'pos': [17.3871941, 78.4939763],
#   'type': 'node'},
#  {'created': {'changeset': '39392811',
#    'timestamp': '2016-05-18T06:58:09Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '2'},
#   'id': '308783093',
#   'pos': [17.3898452, 78.490614],
#   'type': 'node'},
#  {'created': {'changeset': '40946612',
#    'timestamp': '2016-07-22T10:11:49Z',
#    'uid': '2662203',
#    'user': 'Akash Kumar burman',
#    'version': '3'},
#   'id': '308783094',
#   'pos': [17.3894941, 78.4913354],
#   'type': 'node'},
#  {'created': {'changeset': '39393465',
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '2'},
#   'id': '308783095',
#   'pos': [17.3883713, 78.4941801],
#   'type': 'node'},
#  {'created': {'changeset': '39237950',
#    'timestamp': '2016-05-11T10:06:11Z',
#    'uid': '2897134',
#    'user': 'Naresh08',
#    'version': '2'},
#   'id': '308783096',
#   'pos': [17.3879599, 78.4952571],
#   'type': 'node'},
#  {'created': {'changeset': '39393465',
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '2'},
#   'id': '308783097',
#   'pos': [17.3922581, 78.4928365],
#   'type': 'node'},
#  {'created': {'changeset': '39393465',
#    'timestamp': '2016-05-18T07:32:57Z',
#    'uid': '2900516',
#    'user': 'jasvinderkaur',
#    'version': '2'},
#   'id': '308783098',
#   'pos': [17.3920737, 78.4932086],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:51Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783106',
#   'pos': [17.391868, 78.4967284],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:51Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783112',
#   'pos': [17.391393, 78.4982692],
#   'type': 'node'},
#  {'created': {'changeset': '26456608',
#    'timestamp': '2014-10-31T09:29:35Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '308783120',
#   'pos': [17.3980113, 78.4929727],
#   'type': 'node'},
#  {'created': {'changeset': '39442282',
#    'timestamp': '2016-05-20T06:00:38Z',
#    'uid': '2901516',
#    'user': 'bindhu',
#    'version': '6'},
#   'id': '308783121',
#   'pos': [17.3987085, 78.4938066],
#   'type': 'node'},
#  {'created': {'changeset': '26456608',
#    'timestamp': '2014-10-31T09:29:35Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '308783122',
#   'pos': [17.3990553, 78.4941972],
#   'type': 'node'},
#  {'created': {'changeset': '26456608',
#    'timestamp': '2014-10-31T09:29:35Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '2'},
#   'id': '308783124',
#   'pos': [17.3994052, 78.4946058],
#   'type': 'node'},
#  {'created': {'changeset': '26456608',
#    'timestamp': '2014-10-31T09:29:35Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '2'},
#   'id': '308783125',
#   'pos': [17.3995756, 78.4947506],
#   'type': 'node'},
#  {'created': {'changeset': '26456608',
#    'timestamp': '2014-10-31T09:29:35Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '308783127',
#   'pos': [17.4008913, 78.4949222],
#   'type': 'node'},
#  {'created': {'changeset': '13801664',
#    'timestamp': '2012-11-08T20:02:50Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '308783129',
#   'pos': [17.4021288, 78.4950704],
#   'type': 'node'},
#  {'created': {'changeset': '32666643',
#    'timestamp': '2015-07-16T06:27:49Z',
#    'uid': '2996436',
#    'user': 'ravikumar1',
#    'version': '5'},
#   'id': '308783130',
#   'pos': [17.4033852, 78.4953508],
#   'type': 'node'},
#  {'created': {'changeset': '13801664',
#    'timestamp': '2012-11-08T20:02:51Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '3'},
#   'id': '308783131',
#   'pos': [17.4043488, 78.4956089],
#   'type': 'node'},
#  {'created': {'changeset': '13801664',
#    'timestamp': '2012-11-08T20:02:50Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '308783132',
#   'pos': [17.4055078, 78.4960546],
#   'type': 'node'},
#  {'created': {'changeset': '13801664',
#    'timestamp': '2012-11-08T20:02:50Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '5'},
#   'id': '308783133',
#   'pos': [17.4067697, 78.4966106],
#   'type': 'node'},
#  {'created': {'changeset': '26541166',
#    'timestamp': '2014-11-04T04:27:33Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '2'},
#   'id': '308783134',
#   'pos': [17.4082661, 78.4973777],
#   'type': 'node'},
#  {'created': {'changeset': '39442282',
#    'timestamp': '2016-05-20T06:00:38Z',
#    'uid': '2901516',
#    'user': 'bindhu',
#    'version': '5'},
#   'id': '308783136',
#   'pos': [17.4099041, 78.4978346],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:56Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783137',
#   'pos': [17.4111205, 78.4979244],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:56Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783138',
#   'pos': [17.4123184, 78.4977712],
#   'type': 'node'},
#  {'created': {'changeset': '27039817',
#    'timestamp': '2014-11-26T09:13:01Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '308783140',
#   'pos': [17.4138388, 78.4976618],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:56Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783141',
#   'pos': [17.4145472, 78.4978733],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:56Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783142',
#   'pos': [17.4157173, 78.498377],
#   'type': 'node'},
#  {'created': {'changeset': '39307941',
#    'timestamp': '2016-05-14T10:03:04Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '3'},
#   'id': '308783143',
#   'pos': [17.4160213, 78.4985129],
#   'type': 'node'},
#  {'created': {'changeset': '17865591',
#    'timestamp': '2013-09-16T10:53:45Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '308783146',
#   'pos': [17.4194885, 78.5000489],
#   'type': 'node'},
#  {'created': {'changeset': '27039804',
#    'timestamp': '2014-11-26T09:12:27Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '308783147',
#   'pos': [17.4206889, 78.5006218],
#   'type': 'node'},
#  {'created': {'changeset': '38612490',
#    'timestamp': '2016-04-16T06:51:00Z',
#    'uid': '3779589',
#    'user': 'Chenna2701',
#    'version': '2'},
#   'id': '308783148',
#   'pos': [17.4212782, 78.5009416],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:57Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783149',
#   'pos': [17.4218742, 78.5013698],
#   'type': 'node'},
#  {'created': {'changeset': '38854336',
#    'timestamp': '2016-04-25T11:30:42Z',
#    'uid': '2901769',
#    'user': 'anushap',
#    'version': '3'},
#   'id': '308783150',
#   'pos': [17.4223531, 78.5016078],
#   'type': 'node'},
#  {'created': {'changeset': '9067333',
#    'timestamp': '2011-08-19T17:39:12Z',
#    'uid': '250196',
#    'user': 'adivik2000',
#    'version': '2'},
#   'id': '308783152',
#   'pos': [17.4247975, 78.5019289],
#   'type': 'node'},
#  {'created': {'changeset': '39343374',
#    'timestamp': '2016-05-16T05:11:31Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '2'},
#   'id': '308783155',
#   'pos': [17.4284872, 78.5022074],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:58Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783157',
#   'pos': [17.4297719, 78.5043626],
#   'type': 'node'},
#  {'created': {'changeset': '15439464',
#    'timestamp': '2013-03-21T06:49:32Z',
#    'uid': '180306',
#    'user': 'Chaitanya Kumar CH',
#    'version': '2'},
#   'id': '308783159',
#   'pos': [17.4311246, 78.5053217],
#   'type': 'node'},
#  {'created': {'changeset': '630420',
#    'timestamp': '2008-10-30T16:02:58Z',
#    'uid': '61927',
#    'user': 'AlexPleiner',
#    'version': '1'},
#   'id': '308783160',
#   'pos': [17.4323765, 78.5058663],
#   'type': 'node'},
#  {'created': {'changeset': '26703338',
#    'timestamp': '2014-11-11T05:10:48Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '3'},
#   'id': '308783162',
#   'pos': [17.3963248, 78.4963634],
#   'type': 'node'},
#  {'created': {'changeset': '26456442',
#    'timestamp': '2014-10-31T09:20:15Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '2'},
#   'id': '308783163',
#   'pos': [17.3968422, 78.495706],
#   'type': 'node'},
#  {'created': {'changeset': '26456475',
#    'timestamp': '2014-10-31T09:22:01Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '308783164',
#   'pos': [17.3993615, 78.4919039],
#   'type': 'node'},
#  {'created': {'changeset': '26456442',
#    'timestamp': '2014-10-31T09:20:14Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '308783165',
#   'pos': [17.3997501, 78.491356],
#   'type': 'node'},
#  {'created': {'changeset': '26456442',
#    'timestamp': '2014-10-31T09:20:14Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '308783166',
#   'pos': [17.4004245, 78.4899652],
#   'type': 'node'},
#  {'created': {'changeset': '26456442',
#    'timestamp': '2014-10-31T09:20:14Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '308783167',
#   'pos': [17.4006523, 78.4893564],
#   'type': 'node'},
#  {'created': {'changeset': '39289118',
#    'timestamp': '2016-05-13T11:09:25Z',
#    'uid': '2900372',
#    'user': 'Apreethi',
#    'version': '5'},
#   'id': '308783168',
#   'pos': [17.4007922, 78.4887747],
#   'type': 'node'},
#  {'created': {'changeset': '42678162',
#    'timestamp': '2016-10-06T08:47:47Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '5'},
#   'id': '308783169',
#   'pos': [17.4007765, 78.4883398],
#   'type': 'node'},
#  {'created': {'changeset': '42678162',
#    'timestamp': '2016-10-06T08:47:47Z',
#    'uid': '2644101',
#    'user': 'Chetan_Gowda',
#    'version': '10'},
#   'id': '308783170',
#   'pos': [17.4006472, 78.4880622],
#   'type': 'node'},
#  {'created': {'changeset': '25928119',
#    'timestamp': '2014-10-07T21:35:44Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '4'},
#   'id': '308783172',
#   'pos': [17.4011014, 78.4864205],
#   'type': 'node'},
#  {'created': {'changeset': '27196076',
#    'timestamp': '2014-12-03T09:37:26Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '6'},
#   'id': '308783173',
#   'pos': [17.4014382, 78.4855501],
#   'type': 'node'},
#  {'created': {'changeset': '26683407',
#    'timestamp': '2014-11-10T09:33:11Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '308783175',
#   'pos': [17.4022617, 78.4835466],
#   'type': 'node'},
#  {'created': {'changeset': '26454606',
#    'timestamp': '2014-10-31T06:11:53Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '4'},
#   'id': '308783176',
#   'pos': [17.4033331, 78.4825312],
#   'type': 'node'},
#  {'created': {'changeset': '26424761',
#    'timestamp': '2014-10-29T22:32:38Z',
#    'uid': '2226712',
#    'user': 'dannykath',
#    'version': '7'},
#   'id': '308783178',
#   'pos': [17.4050222, 78.4804084],
#   'type': 'node'},
#  {'created': {'changeset': '26683165',
#    'timestamp': '2014-11-10T09:18:59Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '7'},
#   'id': '308783179',
#   'pos': [17.4052986, 78.4800138],
#   'type': 'node'},
#  {'created': {'changeset': '26454606',
#    'timestamp': '2014-10-31T06:11:53Z',
#    'uid': '2419471',
#    'user': 'Baluhyd',
#    'version': '5'},
#   'id': '308783180',
#   'pos': [17.4059801, 78.4789029],
#   'type': 'node'},
#  ...]

# %% [markdown]
# ## OverView of the Data

# %%
# get the database and collection of our data 
# and output the total number of records in collection
from pymongo import MongoClient

client = MongoClient()
db = client.test
db.records.find().count()
# Out:
# 490507

# %% [markdown]
# I have already created database under name 'test' and collection 'records' using the json file created from the data set

# %%
# get our collection from database
record_collection = db.records

# %%
# record which have node tags
record_collection.find({"type":"node"}).count()
# Out:
# 397179

# %%
# records which have way tags
record_collection.find({"type":"way"}).count()
# Out:
# 93328

# %%
# we haven't added relation tags to our database
record_collection.find({"type":"relation"}).count()
# Out:
# 0

# %%
# to get number of unique users using 'uid', who contributed to this part of the map

import pprint
result = record_collection.aggregate( [{ "$group" : { "_id" : "$created.uid", "count" : { "$sum" : 1 }}},
                              { "$sort" : { "count" : -1} },
                              ])
print(len(list(result)))
# Out:
# 393

# %% [markdown]
# As we haven't included 'relation' tags in our database, unique user count is only 393 compared to the count we got from xml data.

# %%
# take a look at number of different amenities in this part of map

result = record_collection.aggregate([{"$match" : { "$or" : [ {"amenity" : { "$eq" : "cafe" } }, 
                                                              {"amenity" : { "$eq" : "bank"}},
                                                              {"amenity" : { "$eq" : "restaurant"}}]}},
                                      {"$group" : { "_id" : "$amenity", "count" : { "$sum" : 1 }}}
                                      ])
pprint.pprint(list(result))
# Out:
# [{'_id': 'cafe', 'count': 48},
#  {'_id': 'bank', 'count': 119},
#  {'_id': 'restaurant', 'count': 92}]

# %% [markdown]
# # Ideas to Improve the DataSet

# %% [markdown]
# I would like to summarise the problems encountered in auditing this part of the data and how I handled them :
#
# 1. The 'key' with 'mahesh' as value, it would be more approriate if it had been 'name', as that node represents the address of a person whose name is 'Mahesh Kumar'. I have changed this while importing the data into MonogoDb.
# 2. I have excluded the 'fixme' nodes, as they need further improvement and it is clearly mentioned that no copyrighted content should be used to improve those nodes in osm website.
#
# >Don't use copyrighted data
# Most data that you find on the web is copyrighted, including "free" maps like Google Maps. You may never use copyrighted resources because it can cause a lot of trouble to OSM. As a rule of thumb, use no external resources except those available in the editors. If you think you found a non-copyrighted resource that isn't available in the editors, please discuss it first with local mappers using contact channels. Reference : http://wiki.openstreetmap.org/wiki/Beginners_Guide_1.1
#
#
#
# 3. A certain postcode which has 7 characters in it, I have striped off the space before converting it to int.
#
# 4. The street names where 'Telangana'( name of the state ) is included. I have stripped off the 'Telangana' and unwanted commas before importing data into MonogoDb

# %% [markdown]
# # Changes made in OpenStreetMap

# %% [markdown]
# I have edited the 'mahesh' tag and renamed it to 'name'. You find the same, in the following changeset of osm.
#
# https://www.openstreetmap.org/changeset/47372134
#
# I have also made following change to previuosly found street name issue, from 'Panjagutta Flyover' to 'Nagarjuna Circle Road'
#
# https://www.openstreetmap.org/changeset/47372250
#
# My username on osm is 'potter13'
